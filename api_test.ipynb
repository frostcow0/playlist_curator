# %%
import requests
import pandas as pd
import json

# %%
user = requests.get('http://localhost:8080/user_data')
# user.json()

# %%
saved = user.json()["feature_saved"]
last = user.json()["feature_50"]

# %%
test = requests.post('http://localhost:8080/test_post/{"your mom":"yea"}')

# %%
pd.read_json(test.json(), orient='index')
# Out:
#             0
# your mom  yea

# %%
type(user.json())
# Out:
# dict

# %%
recommended_dict = requests.post('http://localhost:8080/minkowski_recommend', json=user.json())

# %%
recommended_dict.json()
# Out:
# {'formatted': {'Song Name': {'1': 'AfricAryaN',
#    '2': 'Human Sadness',
#    '3': 'Last Call',
#    '4': 'UFOs (feat. Marian Mereba)',
#    '5': 'Nothing Left To Say / Rocks',
#    '6': 'Untitled',
#    '7': 'Amphetamine',
#    '8': 'Amphetamine',
#    '9': 'Hallelujah',
#    '10': 'Through the Fire and Flames',
#    '11': 'Thank You (ft. Lucy Rose & The RattPack)',
#    '12': 'Bohemian Trapsody',
#    '13': '12.38 (feat. 21 Savage, Ink & Kadhja Bonet)',
#    '14': "Freedom! '90 - Remastered",
#    '15': 'Paranoid Android',
#    '16': 'Money Trees',
#    '17': 'Hapi (with Benji. & EARTHGANG feat. Mereba, Big Rube)',
#    '18': "i'm thinking about horses",
#    '19': 'Sacrifices (with EARTHGANG & J. Cole feat. Smino & Saba)',
#    '20': 'City Of Stars'},
#   'Artist Name': {'1': 'Logic',
#    '2': 'The Voidz',
#    '3': 'Logic',
#    '4': 'EARTHGANG',
#    '5': 'Imagine Dragons',
#    '6': 'Knuckle Puck',
#    '7': 'Smino',
#    '8': 'Smino',
#    '9': 'Logic',
#    '10': 'DragonForce',
#    '11': 'Logic',
#    '12': 'Logic',
#    '13': 'Childish Gambino',
#    '14': 'George Michael',
#    '15': 'Radiohead',
#    '16': 'Kendrick Lamar',
#    '17': 'Spillage Village',
#    '18': 'mansionz',
#    '19': 'Dreamville',
#    '20': 'Logic'}},
#  'raw': {'danceability': {'76ZrqdtkKxhMl42xAQTnFm': 0.529,
#    '3YB9cvd668HXBEq8rbBW8P': 0.231,
#    '202RUoPIUYZLyg6VtosWci': 0.778,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.398,
#    '16hsoq7933Mb069YTs2XYX': 0.267,
#    '7j04glqh2SY6Es6jiQEhgf': 0.266,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.619,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.674,
#    '6nnacTL5on2aVsRhVDNUSo': 0.113,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.599,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.725,
#    '011ZwIM48eD8ee2UBpG8nK': 0.6910000000000001,
#    '3tyTt5pEWblt96j1HsXiV5': 0.677,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.252,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.716,
#    '4WEJJCwa1YupLClYPWj71O': 0.426,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.596,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.8250000000000001,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.466},
#   'energy': {'76ZrqdtkKxhMl42xAQTnFm': 0.8,
#    '3YB9cvd668HXBEq8rbBW8P': 0.752,
#    '202RUoPIUYZLyg6VtosWci': 0.8180000000000001,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.584,
#    '16hsoq7933Mb069YTs2XYX': 0.79,
#    '7j04glqh2SY6Es6jiQEhgf': 0.887,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.532,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.596,
#    '6nnacTL5on2aVsRhVDNUSo': 0.9510000000000001,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.749,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.838,
#    '011ZwIM48eD8ee2UBpG8nK': 0.524,
#    '3tyTt5pEWblt96j1HsXiV5': 0.852,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.849,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.531,
#    '4WEJJCwa1YupLClYPWj71O': 0.491,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.248,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.672,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.869},
#   'key': {'76ZrqdtkKxhMl42xAQTnFm': 10,
#    '3YB9cvd668HXBEq8rbBW8P': 0,
#    '202RUoPIUYZLyg6VtosWci': 8,
#    '4yEwsuxfuOmDGl3xpb3Cms': 9,
#    '16hsoq7933Mb069YTs2XYX': 0,
#    '7j04glqh2SY6Es6jiQEhgf': 6,
#    '3Zau3JcrZcBfw8aVjKGkSX': 5,
#    '7fRfIvHPH6bHdMDjPFwTMh': 11,
#    '6nnacTL5on2aVsRhVDNUSo': 0,
#    '4ut9fdC5ncgcvCo0KaphNY': 10,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 6,
#    '011ZwIM48eD8ee2UBpG8nK': 5,
#    '3tyTt5pEWblt96j1HsXiV5': 5,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 5,
#    '2HbKqm4o0w5wEeEFXm2sD4': 7,
#    '4WEJJCwa1YupLClYPWj71O': 5,
#    '38kjIfRtXsUxXyzhsKwX7i': 0,
#    '7wTA0NKIm6T7nP2kaymU2a': 0,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0},
#   'loudness': {'76ZrqdtkKxhMl42xAQTnFm': -7.025,
#    '3YB9cvd668HXBEq8rbBW8P': -4.744,
#    '202RUoPIUYZLyg6VtosWci': -5.29,
#    '4yEwsuxfuOmDGl3xpb3Cms': -7.773,
#    '16hsoq7933Mb069YTs2XYX': -7.226,
#    '7j04glqh2SY6Es6jiQEhgf': -5.742,
#    '3Zau3JcrZcBfw8aVjKGkSX': -9.554,
#    '7fRfIvHPH6bHdMDjPFwTMh': -8.348,
#    '6nnacTL5on2aVsRhVDNUSo': -4.743,
#    '4ut9fdC5ncgcvCo0KaphNY': -7.12,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': -7.486,
#    '011ZwIM48eD8ee2UBpG8nK': -9.718,
#    '3tyTt5pEWblt96j1HsXiV5': -10.856,
#    '2nTsKOXIVGDf2iPeVQO2Gm': -6.501,
#    '2HbKqm4o0w5wEeEFXm2sD4': -7.355,
#    '4WEJJCwa1YupLClYPWj71O': -8.345,
#    '38kjIfRtXsUxXyzhsKwX7i': -14.576,
#    '7wTA0NKIm6T7nP2kaymU2a': -7.108,
#    '4MM4uzwiYPZpdMvB1u1bC7': -5.818},
#   'mode': {'76ZrqdtkKxhMl42xAQTnFm': 1,
#    '3YB9cvd668HXBEq8rbBW8P': 1,
#    '202RUoPIUYZLyg6VtosWci': 0,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0,
#    '16hsoq7933Mb069YTs2XYX': 1,
#    '7j04glqh2SY6Es6jiQEhgf': 1,
#    '3Zau3JcrZcBfw8aVjKGkSX': 1,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0,
#    '6nnacTL5on2aVsRhVDNUSo': 0,
#    '4ut9fdC5ncgcvCo0KaphNY': 1,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0,
#    '011ZwIM48eD8ee2UBpG8nK': 1,
#    '3tyTt5pEWblt96j1HsXiV5': 1,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 1,
#    '2HbKqm4o0w5wEeEFXm2sD4': 1,
#    '4WEJJCwa1YupLClYPWj71O': 1,
#    '38kjIfRtXsUxXyzhsKwX7i': 0,
#    '7wTA0NKIm6T7nP2kaymU2a': 1,
#    '4MM4uzwiYPZpdMvB1u1bC7': 1},
#   'speechiness': {'76ZrqdtkKxhMl42xAQTnFm': 0.166,
#    '3YB9cvd668HXBEq8rbBW8P': 0.046,
#    '202RUoPIUYZLyg6VtosWci': 0.33,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.176,
#    '16hsoq7933Mb069YTs2XYX': 0.0472,
#    '7j04glqh2SY6Es6jiQEhgf': 0.034800000000000005,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.515,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.195,
#    '6nnacTL5on2aVsRhVDNUSo': 0.129,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.269,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.031200000000000002,
#    '011ZwIM48eD8ee2UBpG8nK': 0.16,
#    '3tyTt5pEWblt96j1HsXiV5': 0.0449,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.058100000000000006,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.122,
#    '4WEJJCwa1YupLClYPWj71O': 0.039400000000000004,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.274,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.418,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.13},
#   'acousticness': {'76ZrqdtkKxhMl42xAQTnFm': 0.155,
#    '3YB9cvd668HXBEq8rbBW8P': 0.231,
#    '202RUoPIUYZLyg6VtosWci': 0.301,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.736,
#    '16hsoq7933Mb069YTs2XYX': 0.12,
#    '7j04glqh2SY6Es6jiQEhgf': 0.00935,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.715,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.495,
#    '6nnacTL5on2aVsRhVDNUSo': 0.00176,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.169,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.012700000000000001,
#    '011ZwIM48eD8ee2UBpG8nK': 0.197,
#    '3tyTt5pEWblt96j1HsXiV5': 0.225,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.037700000000000004,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.0703,
#    '4WEJJCwa1YupLClYPWj71O': 0.137,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.794,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.0858,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.11900000000000001},
#   'instrumentalness': {'76ZrqdtkKxhMl42xAQTnFm': 0.0,
#    '3YB9cvd668HXBEq8rbBW8P': 0.781,
#    '202RUoPIUYZLyg6VtosWci': 0.0,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.0,
#    '16hsoq7933Mb069YTs2XYX': 4.59e-05,
#    '7j04glqh2SY6Es6jiQEhgf': 0.28,
#    '3Zau3JcrZcBfw8aVjKGkSX': 1.33e-05,
#    '7fRfIvHPH6bHdMDjPFwTMh': 3.3800000000000002e-06,
#    '6nnacTL5on2aVsRhVDNUSo': 0.007180000000000001,
#    '4ut9fdC5ncgcvCo0KaphNY': 3.0300000000000002e-06,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.312,
#    '011ZwIM48eD8ee2UBpG8nK': 4.29e-05,
#    '3tyTt5pEWblt96j1HsXiV5': 4.04e-05,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.005920000000000001,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.0,
#    '4WEJJCwa1YupLClYPWj71O': 0.005730000000000001,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.0,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.0,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.030500000000000003},
#   'liveness': {'76ZrqdtkKxhMl42xAQTnFm': 0.0858,
#    '3YB9cvd668HXBEq8rbBW8P': 0.113,
#    '202RUoPIUYZLyg6VtosWci': 0.101,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.187,
#    '16hsoq7933Mb069YTs2XYX': 0.635,
#    '7j04glqh2SY6Es6jiQEhgf': 0.178,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.09530000000000001,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.342,
#    '6nnacTL5on2aVsRhVDNUSo': 0.334,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.4,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.101,
#    '011ZwIM48eD8ee2UBpG8nK': 0.488,
#    '3tyTt5pEWblt96j1HsXiV5': 0.059500000000000004,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.0545,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.224,
#    '4WEJJCwa1YupLClYPWj71O': 0.116,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.0872,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.123,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.233},
#   'valence': {'76ZrqdtkKxhMl42xAQTnFm': 0.356,
#    '3YB9cvd668HXBEq8rbBW8P': 0.115,
#    '202RUoPIUYZLyg6VtosWci': 0.812,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.185,
#    '16hsoq7933Mb069YTs2XYX': 0.0623,
#    '7j04glqh2SY6Es6jiQEhgf': 0.215,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.401,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.46,
#    '6nnacTL5on2aVsRhVDNUSo': 0.139,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.5740000000000001,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.41400000000000003,
#    '011ZwIM48eD8ee2UBpG8nK': 0.41000000000000003,
#    '3tyTt5pEWblt96j1HsXiV5': 0.93,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.194,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.34400000000000003,
#    '4WEJJCwa1YupLClYPWj71O': 0.214,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.189,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.246,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.597},
#   'tempo': {'76ZrqdtkKxhMl42xAQTnFm': 104.058,
#    '3YB9cvd668HXBEq8rbBW8P': 122.901,
#    '202RUoPIUYZLyg6VtosWci': 86.947,
#    '4yEwsuxfuOmDGl3xpb3Cms': 90.364,
#    '16hsoq7933Mb069YTs2XYX': 108.033,
#    '7j04glqh2SY6Es6jiQEhgf': 135.014,
#    '3Zau3JcrZcBfw8aVjKGkSX': 120.019,
#    '7fRfIvHPH6bHdMDjPFwTMh': 136.059,
#    '6nnacTL5on2aVsRhVDNUSo': 200.024,
#    '4ut9fdC5ncgcvCo0KaphNY': 159.413,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 140.053,
#    '011ZwIM48eD8ee2UBpG8nK': 164.047,
#    '3tyTt5pEWblt96j1HsXiV5': 91.689,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 163.704,
#    '2HbKqm4o0w5wEeEFXm2sD4': 71.994,
#    '4WEJJCwa1YupLClYPWj71O': 143.724,
#    '38kjIfRtXsUxXyzhsKwX7i': 112.043,
#    '7wTA0NKIm6T7nP2kaymU2a': 147.01,
#    '4MM4uzwiYPZpdMvB1u1bC7': 90.109},
#   'duration_ms': {'76ZrqdtkKxhMl42xAQTnFm': 728413,
#    '3YB9cvd668HXBEq8rbBW8P': 656901,
#    '202RUoPIUYZLyg6VtosWci': 645667,
#    '4yEwsuxfuOmDGl3xpb3Cms': 541014,
#    '16hsoq7933Mb069YTs2XYX': 536053,
#    '7j04glqh2SY6Es6jiQEhgf': 471660,
#    '3Zau3JcrZcBfw8aVjKGkSX': 469831,
#    '7fRfIvHPH6bHdMDjPFwTMh': 448733,
#    '6nnacTL5on2aVsRhVDNUSo': 441560,
#    '4ut9fdC5ncgcvCo0KaphNY': 430427,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 404667,
#    '011ZwIM48eD8ee2UBpG8nK': 392187,
#    '3tyTt5pEWblt96j1HsXiV5': 390862,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 387213,
#    '2HbKqm4o0w5wEeEFXm2sD4': 386907,
#    '4WEJJCwa1YupLClYPWj71O': 383152,
#    '38kjIfRtXsUxXyzhsKwX7i': 383025,
#    '7wTA0NKIm6T7nP2kaymU2a': 382307,
#    '4MM4uzwiYPZpdMvB1u1bC7': 376640},
#   'time_signature': {'76ZrqdtkKxhMl42xAQTnFm': 4,
#    '3YB9cvd668HXBEq8rbBW8P': 4,
#    '202RUoPIUYZLyg6VtosWci': 4,
#    '4yEwsuxfuOmDGl3xpb3Cms': 4,
#    '16hsoq7933Mb069YTs2XYX': 4,
#    '7j04glqh2SY6Es6jiQEhgf': 4,
#    '3Zau3JcrZcBfw8aVjKGkSX': 4,
#    '7fRfIvHPH6bHdMDjPFwTMh': 4,
#    '6nnacTL5on2aVsRhVDNUSo': 4,
#    '4ut9fdC5ncgcvCo0KaphNY': 4,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 4,
#    '011ZwIM48eD8ee2UBpG8nK': 4,
#    '3tyTt5pEWblt96j1HsXiV5': 4,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 4,
#    '2HbKqm4o0w5wEeEFXm2sD4': 4,
#    '4WEJJCwa1YupLClYPWj71O': 4,
#    '38kjIfRtXsUxXyzhsKwX7i': 4,
#    '7wTA0NKIm6T7nP2kaymU2a': 4,
#    '4MM4uzwiYPZpdMvB1u1bC7': 4},
#   '0': {'76ZrqdtkKxhMl42xAQTnFm': 0.0,
#    '3YB9cvd668HXBEq8rbBW8P': 0.0,
#    '202RUoPIUYZLyg6VtosWci': 0.0,
#    '4yEwsuxfuOmDGl3xpb3Cms': 0.0,
#    '16hsoq7933Mb069YTs2XYX': 1.0,
#    '7j04glqh2SY6Es6jiQEhgf': 1.0,
#    '3Zau3JcrZcBfw8aVjKGkSX': 0.0,
#    '7fRfIvHPH6bHdMDjPFwTMh': 0.0,
#    '6nnacTL5on2aVsRhVDNUSo': 1.0,
#    '4ut9fdC5ncgcvCo0KaphNY': 0.0,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 0.0,
#    '011ZwIM48eD8ee2UBpG8nK': 0.0,
#    '3tyTt5pEWblt96j1HsXiV5': 1.0,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 1.0,
#    '2HbKqm4o0w5wEeEFXm2sD4': 0.0,
#    '4WEJJCwa1YupLClYPWj71O': 0.0,
#    '38kjIfRtXsUxXyzhsKwX7i': 0.0,
#    '7wTA0NKIm6T7nP2kaymU2a': 0.0,
#    '4MM4uzwiYPZpdMvB1u1bC7': 1.0},
#   '1': {'76ZrqdtkKxhMl42xAQTnFm': 1.0,
#    '3YB9cvd668HXBEq8rbBW8P': 1.0,
#    '202RUoPIUYZLyg6VtosWci': 1.0,
#    '4yEwsuxfuOmDGl3xpb3Cms': 1.0,
#    '16hsoq7933Mb069YTs2XYX': 0.0,
#    '7j04glqh2SY6Es6jiQEhgf': 0.0,
#    '3Zau3JcrZcBfw8aVjKGkSX': 1.0,
#    '7fRfIvHPH6bHdMDjPFwTMh': 1.0,
#    '6nnacTL5on2aVsRhVDNUSo': 0.0,
#    '4ut9fdC5ncgcvCo0KaphNY': 1.0,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 1.0,
#    '011ZwIM48eD8ee2UBpG8nK': 1.0,
#    '3tyTt5pEWblt96j1HsXiV5': 0.0,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.0,
#    '2HbKqm4o0w5wEeEFXm2sD4': 1.0,
#    '4WEJJCwa1YupLClYPWj71O': 1.0,
#    '38kjIfRtXsUxXyzhsKwX7i': 1.0,
#    '7wTA0NKIm6T7nP2kaymU2a': 1.0,
#    '4MM4uzwiYPZpdMvB1u1bC7': 0.0},
#   'Year': {'76ZrqdtkKxhMl42xAQTnFm': 20.0,
#    '3YB9cvd668HXBEq8rbBW8P': 17.0,
#    '202RUoPIUYZLyg6VtosWci': 21.0,
#    '4yEwsuxfuOmDGl3xpb3Cms': 17.0,
#    '16hsoq7933Mb069YTs2XYX': 15.0,
#    '7j04glqh2SY6Es6jiQEhgf': 18.0,
#    '3Zau3JcrZcBfw8aVjKGkSX': 20.0,
#    '7fRfIvHPH6bHdMDjPFwTMh': 20.0,
#    '6nnacTL5on2aVsRhVDNUSo': 9.0,
#    '4ut9fdC5ncgcvCo0KaphNY': 21.0,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 22.0,
#    '011ZwIM48eD8ee2UBpG8nK': 23.0,
#    '3tyTt5pEWblt96j1HsXiV5': 20.0,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 0.0,
#    '2HbKqm4o0w5wEeEFXm2sD4': 15.0,
#    '4WEJJCwa1YupLClYPWj71O': 23.0,
#    '38kjIfRtXsUxXyzhsKwX7i': 20.0,
#    '7wTA0NKIm6T7nP2kaymU2a': 22.0,
#    '4MM4uzwiYPZpdMvB1u1bC7': 18.0},
#   'sim': {'76ZrqdtkKxhMl42xAQTnFm': 539369.223,
#    '3YB9cvd668HXBEq8rbBW8P': 467857.222,
#    '202RUoPIUYZLyg6VtosWci': 456623.224,
#    '4yEwsuxfuOmDGl3xpb3Cms': 351970.225,
#    '16hsoq7933Mb069YTs2XYX': 347009.223,
#    '7j04glqh2SY6Es6jiQEhgf': 282616.222,
#    '3Zau3JcrZcBfw8aVjKGkSX': 280787.222,
#    '7fRfIvHPH6bHdMDjPFwTMh': 259689.222,
#    '6nnacTL5on2aVsRhVDNUSo': 252516.232,
#    '4ut9fdC5ncgcvCo0KaphNY': 241383.224,
#    '7Ii2ALuxW7NkLfQPhV4Rn2': 215623.222,
#    '011ZwIM48eD8ee2UBpG8nK': 203143.225,
#    '3tyTt5pEWblt96j1HsXiV5': 201818.226,
#    '2nTsKOXIVGDf2iPeVQO2Gm': 198169.226,
#    '2HbKqm4o0w5wEeEFXm2sD4': 197863.231,
#    '4WEJJCwa1YupLClYPWj71O': 194108.223,
#    '38kjIfRtXsUxXyzhsKwX7i': 193981.223,
#    '7wTA0NKIm6T7nP2kaymU2a': 193263.223,
#    '4MM4uzwiYPZpdMvB1u1bC7': 187596.227}}}
